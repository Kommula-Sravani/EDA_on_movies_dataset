# %%
import pandas as pd
import numpy as np
import sklearn

# %%
data = pd.read_csv('C:/Users/kommula sravani/Desktop/tmdb-movies.csv')

# %%
data.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# 0                      http://www.jurassicworld.com/   Colin Trevorrow
# 1                        http://www.madmaxmovie.com/     George Miller
# 2     http://www.thedivergentseries.movie/#insurgent  Robert Schwentke
# 3  http://www.starwars.com/films/star-wars-episod...       J.J. Abrams
# 4                           http://www.furious7.com/         James Wan
#
#                          tagline  ...  \
# 0              The park is open.  ...
# 1             What a Lovely Day.  ...
# 2     One Choice Can Destroy You  ...
# 3  Every generation has a story.  ...
# 4            Vengeance Hits Home  ...
#
#                                             overview runtime  \
# 0  Twenty-two years after the events of Jurassic ...     124
# 1  An apocalyptic story set in the furthest reach...     120
# 2  Beatrice Prior must confront her inner demons ...     119
# 3  Thirty years after defeating the Galactic Empi...     136
# 4  Deckard Shaw seeks revenge against Dominic Tor...     137
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
# 1  Action|Adventure|Science Fiction|Thriller
# 2         Adventure|Science Fiction|Thriller
# 3   Action|Adventure|Science Fiction|Fantasy
# 4                      Action|Crime|Thriller
#
#                                 production_companies release_date vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15       5562
# 1  Village Roadshow Pictures|Kennedy Miller Produ...      5/13/15       6185
# 2  Summit Entertainment|Mandeville Films|Red Wago...      3/18/15       2480
# 3          Lucasfilm|Truenorth Productions|Bad Robot     12/15/15       5292
# 4  Universal Pictures|Original Film|Media Rights ...       4/1/15       2947
#
#    vote_average  release_year    budget_adj   revenue_adj
# 0           6.5          2015  1.379999e+08  1.392446e+09
# 1           7.1          2015  1.379999e+08  3.481613e+08
# 2           6.3          2015  1.012000e+08  2.716190e+08
# 3           7.5          2015  1.839999e+08  1.902723e+09
# 4           7.3          2015  1.747999e+08  1.385749e+09
#
# [5 rows x 21 columns]

# %%
data.shape
# Out:
# (10866, 21)

# %%
data.describe()
# Out:
#                   id    popularity        budget       revenue       runtime  \
# count   10866.000000  10866.000000  1.086600e+04  1.086600e+04  10866.000000
# mean    66064.177434      0.646441  1.462570e+07  3.982332e+07    102.070863
# std     92130.136561      1.000185  3.091321e+07  1.170035e+08     31.381405
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10596.250000      0.207583  0.000000e+00  0.000000e+00     90.000000
# 50%     20669.000000      0.383856  0.000000e+00  0.000000e+00     99.000000
# 75%     75610.000000      0.713817  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#          vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  10866.000000  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean     217.389748      5.974922   2001.322658  1.755104e+07  5.136436e+07
# std      575.619058      0.935142     12.812941  3.430616e+07  1.446325e+08
# min       10.000000      1.500000   1960.000000  0.000000e+00  0.000000e+00
# 25%       17.000000      5.400000   1995.000000  0.000000e+00  0.000000e+00
# 50%       38.000000      6.000000   2006.000000  0.000000e+00  0.000000e+00
# 75%      145.750000      6.600000   2011.000000  2.085325e+07  3.369710e+07
# max     9767.000000      9.200000   2015.000000  4.250000e+08  2.827124e+09

# %%
data.nunique()
# Out:
# id                      10865
# imdb_id                 10855
# popularity              10814
# budget                    557
# revenue                  4702
# original_title          10571
# cast                    10719
# homepage                 2896
# director                 5067
# tagline                  7997
# keywords                 8804
# overview                10847
# runtime                   247
# genres                   2039
# production_companies     7445
# release_date             5909
# vote_count               1289
# vote_average               72
# release_year               56
# budget_adj               2614
# revenue_adj              4840
# dtype: int64

# %%
movies = data.drop (['imdb_id','popularity','homepage','director','tagline','keywords','overview','production_companies','release_date','vote_count','vote_average','revenue_adj','budget_adj'], axis=1)

# %%
movies.head()
# Out:
#        id     budget     revenue                original_title  \
# 0  135397  150000000  1513528810                Jurassic World
# 1   76341  150000000   378436354            Mad Max: Fury Road
# 2  262500  110000000   295238201                     Insurgent
# 3  140607  200000000  2068178225  Star Wars: The Force Awakens
# 4  168259  190000000  1506249360                     Furious 7
#
#                                                 cast  runtime  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...      124
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...      120
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...      119
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...      136
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...      137
#
#                                       genres  release_year
# 0  Action|Adventure|Science Fiction|Thriller          2015
# 1  Action|Adventure|Science Fiction|Thriller          2015
# 2         Adventure|Science Fiction|Thriller          2015
# 3   Action|Adventure|Science Fiction|Fantasy          2015
# 4                      Action|Crime|Thriller          2015

# %%
sum(movies.duplicated())
# Out:
# 1

# %%
movies.drop_duplicates(inplace=True)
print(sum(movies.duplicated()))
print(movies.shape)
# Out:
# 0
# (10865, 8)

# %%
movies.isnull().sum()
# Out:
# id                 0
# budget             0
# revenue            0
# original_title     0
# cast              76
# runtime            0
# genres            23
# release_year       0
# dtype: int64

# %%
movies = movies.dropna()

# %%
movies.isnull().sum()
# Out:
# id                0
# budget            0
# revenue           0
# original_title    0
# cast              0
# runtime           0
# genres            0
# release_year      0
# dtype: int64

# %%
movies
# Out:
#            id     budget     revenue                original_title  \
# 0      135397  150000000  1513528810                Jurassic World
# 1       76341  150000000   378436354            Mad Max: Fury Road
# 2      262500  110000000   295238201                     Insurgent
# 3      140607  200000000  2068178225  Star Wars: The Force Awakens
# 4      168259  190000000  1506249360                     Furious 7
# ...       ...        ...         ...                           ...
# 10861      21          0           0            The Endless Summer
# 10862   20379          0           0                    Grand Prix
# 10863   39768          0           0           Beregis Avtomobilya
# 10864   21449          0           0        What's Up, Tiger Lily?
# 10865   22293      19000           0      Manos: The Hands of Fate
#
#                                                     cast  runtime  \
# 0      Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...      124
# 1      Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...      120
# 2      Shailene Woodley|Theo James|Kate Winslet|Ansel...      119
# 3      Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...      136
# 4      Vin Diesel|Paul Walker|Jason Statham|Michelle ...      137
# ...                                                  ...      ...
# 10861  Michael Hynson|Robert August|Lord 'Tally Ho' B...       95
# 10862  James Garner|Eva Marie Saint|Yves Montand|Tosh...      176
# 10863  Innokentiy Smoktunovskiy|Oleg Efremov|Georgi Z...       94
# 10864  Tatsuya Mihashi|Akiko Wakabayashi|Mie Hama|Joh...       80
# 10865  Harold P. Warren|Tom Neyman|John Reynolds|Dian...       74
#
#                                           genres  release_year
# 0      Action|Adventure|Science Fiction|Thriller          2015
# 1      Action|Adventure|Science Fiction|Thriller          2015
# 2             Adventure|Science Fiction|Thriller          2015
# 3       Action|Adventure|Science Fiction|Fantasy          2015
# 4                          Action|Crime|Thriller          2015
# ...                                          ...           ...
# 10861                                Documentary          1966
# 10862                     Action|Adventure|Drama          1966
# 10863                             Mystery|Comedy          1966
# 10864                              Action|Comedy          1966
# 10865                                     Horror          1966
#
# [10767 rows x 8 columns]

# %%
for x in movies.index:
    if movies.loc[x, "budget"] < 10000:
        movies.drop(x, inplace = True)

# %%
movies
# Out:
#            id     budget     revenue                original_title  \
# 0      135397  150000000  1513528810                Jurassic World
# 1       76341  150000000   378436354            Mad Max: Fury Road
# 2      262500  110000000   295238201                     Insurgent
# 3      140607  200000000  2068178225  Star Wars: The Force Awakens
# 4      168259  190000000  1506249360                     Furious 7
# ...       ...        ...         ...                           ...
# 10835    5923   12000000    20000000              The Sand Pebbles
# 10841   42701      75000           0                  The Shooting
# 10848    2161    5115000    12000000              Fantastic Voyage
# 10855   13343     700000           0       The Ghost & Mr. Chicken
# 10865   22293      19000           0      Manos: The Hands of Fate
#
#                                                     cast  runtime  \
# 0      Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...      124
# 1      Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...      120
# 2      Shailene Woodley|Theo James|Kate Winslet|Ansel...      119
# 3      Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...      136
# 4      Vin Diesel|Paul Walker|Jason Statham|Michelle ...      137
# ...                                                  ...      ...
# 10835  Steve McQueen|Richard Attenborough|Richard Cre...      182
# 10841  Will Hutchins|Millie Perkins|Jack Nicholson|Wa...       82
# 10848  Stephen Boyd|Raquel Welch|Edmond O'Brien|Donal...      100
# 10855  Don Knotts|Joan Staley|Liam Redmond|Dick Sarge...       90
# 10865  Harold P. Warren|Tom Neyman|John Reynolds|Dian...       74
#
#                                           genres  release_year
# 0      Action|Adventure|Science Fiction|Thriller          2015
# 1      Action|Adventure|Science Fiction|Thriller          2015
# 2             Adventure|Science Fiction|Thriller          2015
# 3       Action|Adventure|Science Fiction|Fantasy          2015
# 4                          Action|Crime|Thriller          2015
# ...                                          ...           ...
# 10835         Action|Adventure|Drama|War|Romance          1966
# 10841                                    Western          1966
# 10848                  Adventure|Science Fiction          1966
# 10855              Comedy|Family|Mystery|Romance          1966
# 10865                                     Horror          1966
#
# [5093 rows x 8 columns]

# %%
for x in movies.index:
    if movies.loc[x, 'revenue'] < 5000 :
        movies.drop(x,inplace = True)

# %%
movies.drop(movies[movies['runtime']== 0].index, inplace = True)

# %%
movies
# Out:
#            id     budget     revenue                   original_title  \
# 0      135397  150000000  1513528810                   Jurassic World
# 1       76341  150000000   378436354               Mad Max: Fury Road
# 2      262500  110000000   295238201                        Insurgent
# 3      140607  200000000  2068178225     Star Wars: The Force Awakens
# 4      168259  190000000  1506249360                        Furious 7
# ...       ...        ...         ...                              ...
# 10822     396    7500000    33736689  Who's Afraid of Virginia Woolf?
# 10828    5780    3000000    13000000                     Torn Curtain
# 10829    6644    4653000     6000000                        El Dorado
# 10835    5923   12000000    20000000                 The Sand Pebbles
# 10848    2161    5115000    12000000                 Fantastic Voyage
#
#                                                     cast  runtime  \
# 0      Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...      124
# 1      Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...      120
# 2      Shailene Woodley|Theo James|Kate Winslet|Ansel...      119
# 3      Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...      136
# 4      Vin Diesel|Paul Walker|Jason Statham|Michelle ...      137
# ...                                                  ...      ...
# 10822  Elizabeth Taylor|Richard Burton|George Segal|S...      131
# 10828  Paul Newman|Julie Andrews|Lila Kedrova|Hansj̦...      128
# 10829  John Wayne|Robert Mitchum|James Caan|Charlene ...      120
# 10835  Steve McQueen|Richard Attenborough|Richard Cre...      182
# 10848  Stephen Boyd|Raquel Welch|Edmond O'Brien|Donal...      100
#
#                                           genres  release_year
# 0      Action|Adventure|Science Fiction|Thriller          2015
# 1      Action|Adventure|Science Fiction|Thriller          2015
# 2             Adventure|Science Fiction|Thriller          2015
# 3       Action|Adventure|Science Fiction|Fantasy          2015
# 4                          Action|Crime|Thriller          2015
# ...                                          ...           ...
# 10822                                      Drama          1966
# 10828                           Mystery|Thriller          1966
# 10829                             Action|Western          1966
# 10835         Action|Adventure|Drama|War|Romance          1966
# 10848                  Adventure|Science Fiction          1966
#
# [3807 rows x 8 columns]

# %% [markdown]
# # Which are the movies with the third lowest and third highest budget?

# %%
budget_movies = movies.sort_values(by ='budget', ascending=False).head(3)
budget_movies
# Out:
#          id     budget     revenue  \
# 2244  46528  425000000    11087569
# 3375   1865  380000000  1021683000
# 7387    285  300000000   961000000
#
#                                    original_title  \
# 2244                            The Warrior's Way
# 3375  Pirates of the Caribbean: On Stranger Tides
# 7387     Pirates of the Caribbean: At World's End
#
#                                                    cast  runtime  \
# 2244  Kate Bosworth|Jang Dong-gun|Geoffrey Rush|Dann...      100
# 3375  Johnny Depp|Pen̩lope Cruz|Geoffrey Rush|Ian M...      136
# 7387  Johnny Depp|Orlando Bloom|Keira Knightley|Geof...      169
#
#                                          genres  release_year  year
# 2244  Adventure|Fantasy|Action|Western|Thriller          2010  1970
# 3375                   Adventure|Action|Fantasy          2011  1970
# 7387                   Adventure|Fantasy|Action          2007  1970

# %%
budget_movies = movies.sort_values(by ='budget', ascending=False).tail(3)
budget_movies
# Out:
#          id  budget    revenue       original_title  \
# 7447  23827   15000  193355800  Paranormal Activity
# 7277    692   12000    6000000       Pink Flamingos
# 1354    985   10000    7000000           Eraserhead
#
#                                                    cast  runtime  \
# 7447  Katie Featherston|Micah Sloat|Mark Fredrichs|A...       86
# 7277  Divine|David Lochary|Mary Vivian Pearce|Mink S...       93
# 1354  Jack Nance|Charlotte Stewart|Allen Joseph|Jean...       89
#
#                                     genres  release_year
# 7447                        Horror|Mystery          2007
# 7277                                Comedy          1972
# 1354  Science Fiction|Fantasy|Horror|Drama          1977

# %% [markdown]
# ## Which are the movies with most and least earned revenue?

# %%
high = movies['revenue'].max()
movies[movies['revenue'] == high]['original_title']
# Out:
# 1386    Avatar
# Name: original_title, dtype: object

# %%
low = movies['revenue'].min()
movies[movies['revenue'] == low]['original_title']
# Out:
# 3752    The Good Doctor
# Name: original_title, dtype: object

# %% [markdown]
# # What is the average runtime of movies in the year 2006?

# %%
movies.groupby('release_year').mean()['runtime']
# Out:
# release_year
# 1960    130.000000
# 1961    132.500000
# 1962    141.285714
# 1963    153.500000
# 1964    122.428571
# 1965    167.600000
# 1966    132.200000
# 1967    118.384615
# 1968    130.777778
# 1969    127.500000
# 1970    121.454545
# 1971    112.615385
# 1972    113.000000
# 1973    111.916667
# 1974    122.000000
# 1975    119.333333
# 1976    118.333333
# 1977    108.789474
# 1978    121.500000
# 1979    115.437500
# 1980    113.304348
# 1981    105.133333
# 1982    113.640000
# 1983    107.677419
# 1984    108.619048
# 1985    104.400000
# 1986    104.957447
# 1987    103.304348
# 1988    104.642857
# 1989    106.705882
# 1990    108.000000
# 1991    110.163265
# 1992    112.830189
# 1993    111.794118
# 1994    109.274194
# 1995    112.454545
# 1996    109.905882
# 1997    114.722222
# 1998    111.271739
# 1999    108.850877
# 2000    109.169811
# 2001    109.008264
# 2002    106.984000
# 2003    108.982906
# 2004    107.068966
# 2005    109.717791
# 2006    108.255952
# 2007    107.876543
# 2008    108.560241
# 2009    106.872832
# 2010    106.813559
# 2011    106.463918
# 2012    107.638158
# 2013    109.269663
# 2014    109.296970
# 2015    110.868750
# Name: runtime, dtype: float64

# %%
movies[movies['release_year'] == 2006]['runtime'].mean()
# Out:
# 108.25595238095238

# %% [markdown]
# # What is the average number of words in movie titles between the year 2000-2005?

# %%
movies['year'] = pd.DatetimeIndex(movies['release_year']).year
movies['original_title'].str.split().str.len()
# Out:
# 0        2
# 1        4
# 2        1
# 3        5
# 4        2
#         ..
# 10822    5
# 10828    2
# 10829    2
# 10835    3
# 10848    2
# Name: original_title, Length: 3807, dtype: int64

# %%
movies[movies['release_year'].between(2000,2005)]['original_title'].str.split().str.len().mean()
# Out:
# 2.694980694980695

# %% [markdown]
# # What is the most common Genre for Vin Diesel & Emma Watson movies?

# %%
def tit_for_tat(data1, column2, data1_column):
    dataset_temp = movies.copy()
    dataset_temp[data1_column] = dataset_temp[data1_column].str.contains(data1)
    dataset_temp.drop(dataset_temp[dataset_temp[data1_column] == False].index, inplace = True)
    dataset_temp.drop([ "budget", "revenue", "original_title", "runtime", "release_year"], axis = 1, inplace = True)
    dataset_temp.insert(0, 'New_ID', range(0, len(dataset_temp)))
    
    set_genre = set()
    for temp_genre in dataset_temp[column2].str.split('|').values:
        if isinstance(temp_genre, float): continue
        set_genre = set_genre.union(temp_genre)
        
    genre_count = dict()
    for s in set_genre: genre_count[s] = 0
    for temp_genre in dataset_temp[column2].str.split('|'):        
        if type(temp_genre) == float and pd.isnull(temp_genre): continue        
        for s in [s for s in temp_genre if s in set_genre]: 
            if pd.notnull(s): genre_count[s] += 1
    genre_occurences = []
    for k,v in genre_count.items():
        genre_occurences.append([k,v])
    genre_occurences.sort(key = lambda x:x[1], reverse = True)
    return genre_occurences, genre_count

count, count1 = tit_for_tat("Vin Diesel", 'genres', 'cast')
print(str("The most common genre of movies performed by Vin Diesel is :- \n" + str(count[:1]) + "\n"))
count, count1 = tit_for_tat("Emma Watson", 'genres', 'cast')
print(str("The most common genre of movies performed by Emma Watson is :- \n" + str(count[:1])))
# Out:
# The most common genre of movies performed by Vin Diesel is :-
# [['Action', 14]]
#
# The most common genre of movies performed by Emma Watson is :-
# [['Adventure', 9]]
